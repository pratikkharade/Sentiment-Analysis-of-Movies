# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import csv

# %%
train = pd.read_csv('data//roberta//roberta.train.csv')
train_x = train.iloc[:,:-1]
train_y = train.iloc[:,-1:]

test = pd.read_csv('data//roberta//roberta.test.csv')
test_x = test.iloc[:,:-1]
test_y = test.iloc[:,-1:]

eval_df = pd.read_csv('data//roberta//roberta.eval.anon.csv')
eval_df = eval_df.iloc[:,:-1]

# %%
train_y = train_y.replace(0, -1)
test_y = test_y.replace(0, -1)

# %%
def prediction(x, y, w, b):
    pred = np.dot(w.transpose(), x) + b
    if (pred > 0 and y == 1) or (pred < 0 and y == -1):
        return True
    else:
        return False

def accuracy(feature_df, label_df, w, b):
    size = feature_df.shape[0]
    count = 0
    for i in range(size):
        x = feature_df.iloc[i].tolist()
        y = label_df.iloc[i].tolist()[0]
        if prediction(x, y, w, b):
            count += 1
    return (count/size)

def prediction_value(x, w, b):
    pred = np.dot(w.transpose(), x) + b
    if pred > 0:
        return 1
    else:
        return 0

def get_predicted_list(feature_df, w, b):
    pred_list = []
    size = feature_df.shape[0]
    count = 0
    for i in range(size):
        x = feature_df.iloc[i].tolist()
        pred_list.append(prediction_value(x, w, b))
    return pred_list

def generate_w_b(size):
    np.random.seed(90)
    w = np.array(np.random.normal(-0.01, 0.01, size))
    w_a = np.array(np.random.normal(-0.01, 0.01, size))
    b = np.random.normal(-0.01, 0.01)
    b_a = np.random.normal(-0.01, 0.01)
    return w, b, w_a, b_a

def update_w_b(x, y, w, b, w_a, b_a, lr, update_count):
    eq = y*(np.dot(w.transpose(), x) + b)
    x = np.array(x)
    if eq < 0:
        w = w + lr*y*x
        b = b + lr*y
        update_count += 1
    w_a = w_a + w
    b_a = b_a + b
    return w, b, w_a, b_a, update_count

def perceptron(features, labels, w, b, w_a, b_a, lr, epochs, dev=False, test_df_x=None, test_df_y=None):
    w_list = []
    b_list = []
    update_count = 0
    accuracies_list = []
    index_list = np.arange(features.shape[0])
    for e in range(epochs):
        print("epoch:", e)
        np.random.seed(e)
        np.random.shuffle(index_list)
        for i in index_list:
            x = features.iloc[i].tolist()
            y = labels.iloc[i].tolist()[0]
            w, b, w_a, b_a, update_count = update_w_b(x, y, w, b, w_a, b_a, lr, update_count)
        if dev:
            b_list.append(b_a)
            w_list.append(w_a.copy())
            acc = accuracy(test_df_x, test_df_y, w_a, b_a)
            accuracies_list.append(acc)
            print("Developmental dataset accuracy for epoch", e, "=", acc)
    if dev:
        return w, b, w_a, b_a, accuracies_list, update_count, w_list, b_list
    else:
        return w, b, w_a, b_a, update_count

# %%
#CROSS VALIDATION
k = 5
epochs = 20
lrs = [1, 0.1, 0.01]

train_length = int(train_x.shape[0]*4//5)
test_length = train_x.shape[0] - train_length

train_x_fold = train_x.head(train_length)
train_y_fold = train_y.head(train_length)

test_x_fold = train_x.tail(test_length)
test_y_fold = train_y.tail(test_length)

accuracies = {}

for lr in lrs:
    print("lr:", lr)
    w, b, w_a, b_a = generate_w_b(train_x.shape[1])
    w, b, w_a, b_a, update_count = perceptron(train_x, train_y, w, b, w_a, b_a, lr, epochs)
    acc = accuracy(test_x_fold, test_y_fold, w_a, b_a)
    accuracies[lr] = acc
print(accuracies)
# Out:
# lr: 1
# epoch: 0
# epoch: 1
# epoch: 2
# epoch: 3
# epoch: 4
# epoch: 5
# epoch: 6
# epoch: 7
# epoch: 8
# epoch: 9
# epoch: 10
# epoch: 11
# epoch: 12
# epoch: 13
# epoch: 14
# epoch: 15
# epoch: 16
# epoch: 17
# epoch: 18
# epoch: 19
# lr: 0.1
# epoch: 0
# epoch: 1
# epoch: 2
# epoch: 3
# epoch: 4
# epoch: 5
# epoch: 6
# epoch: 7
# epoch: 8
# epoch: 9
# epoch: 10
# epoch: 11
# epoch: 12
# epoch: 13
# epoch: 14
# epoch: 15
# epoch: 16
# epoch: 17
# epoch: 18
# epoch: 19
# lr: 0.01
# epoch: 0
# epoch: 1
# epoch: 2
# epoch: 3
# epoch: 4
# epoch: 5
# epoch: 6
# epoch: 7
# epoch: 8
# epoch: 9
# epoch: 10
# epoch: 11
# epoch: 12
# epoch: 13
# epoch: 14
# epoch: 15
# epoch: 16
# epoch: 17
# epoch: 18
# epoch: 19
# {1: 0.8166431593794076, 0.1: 0.8187588152327221, 0.01: 0.8187588152327221}

# %%
best_lr = max(accuracies, key = lambda x: accuracies[x])
lr = best_lr
print("Best LR:", lr)
epochs = 20

w, b, w_a, b_a = generate_w_b(train_x.shape[1])
w, b, w_a, b_a, accuracies_list, update_count, w_list, b_list = perceptron(train_x, train_y, w, b, w_a, b_a, lr, epochs, True, test_x_fold, test_y_fold)

print()
print("Total number of updates on training set:", update_count)
print("Max accuracy in developmental dataset:", max(accuracies_list))
index = accuracies_list.index(max(accuracies_list))
print("Max accuracy in developmental dataset was found at epoch number:", index)
best_w = w_list[index]
best_b = b_list[index]
print("Train accuracy with w and b corresponding to best accuracy for dev dataset =", accuracy(train_x, train_y, best_w, best_b))
print("Test accuracy with w and b corresponding to best accuracy for dev dataset =", accuracy(test_x, test_y, best_w, best_b))
print()
# Out:
# Best LR: 0.1
# epoch: 0
# Developmental dataset accuracy for epoch 0 = 0.7440056417489421
# epoch: 1
# Developmental dataset accuracy for epoch 1 = 0.7813822284908322
# epoch: 2
# Developmental dataset accuracy for epoch 2 = 0.7856135401974612
# epoch: 3
# Developmental dataset accuracy for epoch 3 = 0.7961918194640338
# epoch: 4
# Developmental dataset accuracy for epoch 4 = 0.7976022566995769
# epoch: 5
# Developmental dataset accuracy for epoch 5 = 0.7961918194640338
# epoch: 6
# Developmental dataset accuracy for epoch 6 = 0.8004231311706629
# epoch: 7
# Developmental dataset accuracy for epoch 7 = 0.8046544428772919
# epoch: 8
# Developmental dataset accuracy for epoch 8 = 0.806064880112835
# epoch: 9
# Developmental dataset accuracy for epoch 9 = 0.8081805359661495
# epoch: 10
# Developmental dataset accuracy for epoch 10 = 0.8110014104372355
# epoch: 11
# Developmental dataset accuracy for epoch 11 = 0.810296191819464
# epoch: 12
# Developmental dataset accuracy for epoch 12 = 0.8124118476727785
# epoch: 13
# Developmental dataset accuracy for epoch 13 = 0.814527503526093
# epoch: 14
# Developmental dataset accuracy for epoch 14 = 0.8173483779971791
# epoch: 15
# Developmental dataset accuracy for epoch 15 = 0.8187588152327221
# epoch: 16
# Developmental dataset accuracy for epoch 16 = 0.8187588152327221
# epoch: 17
# Developmental dataset accuracy for epoch 17 = 0.8194640338504936
# epoch: 18
# Developmental dataset accuracy for epoch 18 = 0.8208744710860366
# epoch: 19
# Developmental dataset accuracy for epoch 19 = 0.8187588152327221
#
# Total number of updates on training set: 51064
# Max accuracy in developmental dataset: 0.8208744710860366
# Max accuracy in developmental dataset was found at epoch number: 18
# Train accuracy with w and b corresponding to best accuracy for dev dataset = 0.8096783295711061
# Test accuracy with w and b corresponding to best accuracy for dev dataset = 0.7992100065832785

# %%
pred = get_predicted_list(eval_df, best_w, best_b)

# %%
file = open('2_avgPerceptron_roberta_90s_20e.csv', 'w', newline ='')

with file:
    header = ['example_id', 'label']
    writer = csv.DictWriter(file, fieldnames = header)

    writer.writeheader()
    for i in range(len(pred)):
        writer.writerow({'example_id' : i, 'label': pred[i]})
